# %% [markdown]
# # 데이터 과학 진행과정

# %% [markdown]
# # 1: 연구목표 설정

# %% [markdown]
# ## 연구 목표 정의

# %% [markdown]
# ## 프로젝트 사명사 작성

# %% [markdown]
# # 2: 데이터 획득

# %% [markdown]
# ## 내부 데이터

# %% [markdown]
# ### 데이터 조회

# %% [markdown]
# ### 데이터 소유권

# %% [markdown]
# ## 외부 데이터

# %% [markdown]
# # 3: 데이터 준비

# %% [markdown]
# ## 데이터 정제

# %% [markdown]
# ### 데이터 입력 오류

# %% [markdown]
# ### 불가능한 값

# %% [markdown]
# ### 결측값

# %% [markdown]
# ### 이상점

# %% [markdown]
# ### 공백, 오탈자, ...

# %% [markdown]
# ### 코드북의 오류

# %% [markdown]
# ## 데이터 변환

# %% [markdown]
# ### 데이터 집계

# %% [markdown]
# ### 데이터 추정

# %% [markdown]
# ### 파생된 척도

# %% [markdown]
# ### 가변수 생성

# %% [markdown]
# ### 변수의 개수 줄이기

# %% [markdown]
# ## 데이터 조합

# %% [markdown]
# ### 데이터셋의 병합/결합

# %% [markdown]
# ### 집합 연산자

# %% [markdown]
# ### 뷰 생성

# %% [markdown]
# # 4: 데이터 탐색

# %% [markdown]
# ## 단순 그래프

# %% [markdown]
# ## 복합 그래프

# %% [markdown]
# ## 연결과 빗질

# %% [markdown]
# ## 비그래픽 기법

# %% [markdown]
# # 5: 데이터 모델링

# %% [markdown]
# ## 모델 및 변수 선택

# %% [markdown]
# ## 모델링 실시

# %% [markdown]
# ## 모델 진단과 모델 비교

# %% [markdown]
# # 6: 발표 및 자동화

# %% [markdown]
# ## 데이터 발표

# %% [markdown]
# ## 데이터 분석 자동화
